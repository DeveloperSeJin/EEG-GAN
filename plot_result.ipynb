# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 준비
metrics = ["BLEU-1", "BLEU-2", "BLEU-3", "BLEU-4", "ROUGE-1 F", "ROUGE-2 F", "ROUGE-L F", "WER", "CER"]
baseline = [0.15, 0.03, 0.01, 0.00, 0.11, 0.01, 0.09, 1.15, 0.86]
baseline_tf = [0.37, 0.19, 0.09, 0.05, 0.25, 0.04, 0.23, 0.81, 0.63]
# 제공된 데이터
eeg_gan = [
    0.1354146730562201,  # BLEU-1
    0.03483523451768669, # BLEU-2
    0.01047221671105945, # BLEU-3
    0.003676037943873327, # BLEU-4
    0.09270870592510921, # ROUGE-1 F
    0.009229432903578486, # ROUGE-2 F
    0.07903488532741329,  # ROUGE-L F
    1.166046404778314,    # WER
    0.9333650898530237    # CER
]

# TF 적용된 제공 데이터
eeg_gan_tf = [
    0.3964835085353988,   # BLEU-1
    0.2669874383349663,   # BLEU-2
    0.20927478759798668,  # BLEU-3
    0.18086233380276126,  # BLEU-4
    0.2905815082774789,   # ROUGE-1 F
    0.1431823272100932,   # ROUGE-2 F
    0.2807748638741893,   # ROUGE-L F
    0.7654950608775557,   # WER
    0.6198821423357944    # CER
]

# Plot 생성
fig, axes = plt.subplots(1, 2, figsize=(14, 6))  # 두 개의 subplot 생성

# Baseline vs EEG-GAN
x = np.arange(len(metrics))
width = 0.35
axes[0].bar(x - width/2, baseline, width, label='Baseline')
axes[0].bar(x + width/2, eeg_gan, width, label='EEG-GAN')
axes[0].set_title('Baseline vs EEG-GAN')
axes[0].set_xticks(x)
axes[0].set_xticklabels(metrics)
axes[0].legend()
axes[0].set_ylabel('Scores')
axes[0].set_xlabel('Metrics')

# Baseline with TF vs EEG-GAN with TF
axes[1].bar(x - width/2, baseline_tf, width, label='Baseline + TF')
axes[1].bar(x + width/2, eeg_gan_tf, width, label='EEG-GAN + TF')
axes[1].set_title('Baseline with TF vs EEG-GAN with TF')
axes[1].set_xticks(x)
axes[1].set_xticklabels(metrics)
axes[1].legend()
axes[1].set_xlabel('Metrics')

# 그래프 레이아웃 설정 및 출력
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 준비
metrics = ["BLEU-1", "BLEU-2", "BLEU-3", "BLEU-4", "ROUGE-1 F", "ROUGE-2 F", "ROUGE-L F", "WER", "CER"]
baseline = [0.15, 0.03, 0.01, 0.00, 0.11, 0.01, 0.09, 1.15, 0.86]
eeg_gan = [0.14, 0.04, 0.01, 0.00, 0.09, 0.01, 0.08, 1.17, 0.93]

baseline_tf = [0.37, 0.19, 0.09, 0.05, 0.25, 0.04, 0.23, 0.81, 0.63]
eeg_gan_tf = [0.40, 0.27, 0.21, 0.18, 0.29, 0.14, 0.29, 0.77, 0.62]

# Plot 생성
fig, axes = plt.subplots(1, 2, figsize=(14, 6))  # 두 개의 subplot 생성

# Baseline vs EEG-GAN
x = np.arange(len(metrics))
width = 0.35
axes[0].bar(x - width/2, baseline, width, label='Baseline')
axes[0].bar(x + width/2, eeg_gan, width, label='EEG-GAN')
axes[0].set_title('Baseline vs EEG-GAN')
axes[0].set_xticks(x)
axes[0].set_xticklabels(metrics)
axes[0].legend()
axes[0].set_ylabel('Scores')
axes[0].set_xlabel('Metrics')

# Baseline with TF vs EEG-GAN with TF
axes[1].bar(x - width/2, baseline_tf, width, label='Baseline + TF')
axes[1].bar(x + width/2, eeg_gan_tf, width, label='EEG-GAN + TF')
axes[1].set_title('Baseline with TF vs EEG-GAN with TF')
axes[1].set_xticks(x)
axes[1].set_xticklabels(metrics)
axes[1].legend()
axes[1].set_xlabel('Metrics')

# 그래프 레이아웃 설정 및 출력
plt.tight_layout()
plt.show()
